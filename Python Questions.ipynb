# %%
students={
    "Rahul":75, #item
    "Amit":32,
    "Priya":88,
    "Neha":39,
    "Rohit":55
}
for name,marks in students.items():
    if marks>=40:
         print(name,"Pass")
    else:
        print(name,"Fail")
# Out:
# Rahul Pass
# Amit Fail
# Priya Pass
# Neha Fail
# Rohit Pass

# %%
students={
    "Rahul":75, #item
    "Amit":32,
    "Priya":88,
    "Neha":39,
    "Rohit":55
}
for name,marks in students.items():
    if marks >=80:
        print(name,"Excellent")
    elif marks >=60:
        print(name,"Good")
    elif marks>=40:
        print(name,"Average")
    else:
        print(name,"Fail")
# Out:
# Rahul Good
# Amit Fail
# Priya Excellent
# Neha Fail
# Rohit Average

# %%
products={
    "Laptop": 10,
    "House": 3,
    "Keyboard": 0,
    "Monitor": 7,
    "Printer": 2
}
for item,stock in products.items():
    if stock<= 5:
        print(item,"Low Stock")
    elif stock > 5:
        print(item,"Available")
    else:
        print(item,"Out Of Stock")
# Out:
# Laptop Available
# House Low Stock
# Keyboard Low Stock
# Monitor Available
# Printer Low Stock

# %%
employees={ 
    "Rahul":{"Salary": 60000,"department":"IT"},
    "Amit":{"Salary": 40000,"department":"HR"},
    "Priya":{"Salary": 70000,"department":"IT"},
    "Neha":{"Salary": 60000,"department":"Finance"}
}
for name,data in employees.items():
    salary=data["Salary"]
    department=data["department"]
    if salary>= 50000:
        if  department== "IT":
            print(name,"Senior IT Employee")
        elif department== "HR":
            print(name,"Senior HR Employee")
        else:
            print(name,"Senior Employee")
    else:
        print(name,"Junior Employee")
# Out:
# Rahul Senior IT Employee
# Amit Junior Employee
# Priya Senior IT Employee
# Neha Senior Employee

# %%
data={
    "a":10,
    "b":15,
    "c":25,
    "d":30,
    "e":40
}
for lett,value in data.items():
    if value>=0:
        if value>=20:
            print(lett,"Large Even")
        else:
            print(lett,"Even")
    else:
        print(lett,"Odd")
# Out:
# a Even
# b Even
# c Large Even
# d Large Even
# e Large Even

# %%
products={
    "mobile":15000,
    "mouse":500,
    "laptop":60000,
    "keyboard":1200
}
for item,price in products.items():
    if price>=1000:
        if price>=5000:
             print(item,"Premium Product")
        else:
            print(item,"Expensive Product")
    else:
        print(item,"Affordable Product")
# Out:
# mobile Premium Product
# mouse Affordable Product
# laptop Premium Product
# keyboard Expensive Product

# %%
students={
    "Rahul":{"attendance":85,"Marks":70},
    "Amit":{"attendance":60,"Marks":80},
    "Priya":{"attendance":90,"Marks":35},
    "Neha":{"attendance":78,"Marks":55}
}
for name,data in students.items():
    attendance=data["attendance"]
    Marks=data["Marks"]
    if attendance>=75:
        if Marks>=40:
            print(name,"Eligible")
        else:
            print(name,"Failed in Exam")
    else:
        print(name,"Not Eligible")
# Out:
# Rahul Eligible
# Amit Not Eligible
# Priya Failed in Exam
# Neha Eligible

# %%
accounts={
    "Rahul":25000,
    "Amit":5000,
    "Priya":0,
    "Neha": -2000
}
for name,amount in accounts.items():
    if  amount>0:
        if amount>=10000:
            print(name,"Premium Account")
        else:
            print(name,"Regular Account")
    elif amount==0:
        print(name,"No Balance")
    else:
        print(name,"overdraft")
# Out:
# Rahul Premium Account
# Amit Regular Account
# Priya No Balance
# Neha overdraft

# %%
employees = {
    "Rahul": {"salary": 60000, "experience": 6},
    "Aman": {"salary": 45000, "experience": 4},
    "Priya": {"salary": 55000, "experience": 3},
    "Neha": {"salary": 40000, "experience": 2}
}
for name, data in employees.items():
    salary=data["salary"]
    experience=data["experience"]
    if salary>=50000:
        if experience>=5:
            print(name,"Senior")
        else:
            print(name,"Mid Level")
    else:
        if experience>=3:
            print(name,"Experienced Junior")
        else:
            print(name,"Junior/Fresher")
# Out:
# Rahul Senior
# Aman Experienced Junior
# Priya Mid Level
# Neha Junior/Fresher

# %%
students = {
    "Rahul": {"marks": 85, "attendance": 90},
    "Amit": {"marks": 35, "attendance": 80},
    "Priya": {"marks": 65, "attendance": 70},
    "Neha": {"marks": 45, "attendance": 85},
    "Rohit": {"marks": 90, "attendance": 60}
}
for name,data in students.items():
    marks=data["marks"]
    attendance=data["attendance"]
    if attendance<75:
        print(name,"Not Eligible")
    else:
        if marks>=80:
            print(name,"Distintion")
        elif marks>=60:
            print(name,"First Division")
        elif marks>=40:
            print(name,"Pass")
        else:
            print(name,"Fail")
# Out:
# Rahul Distintion
# Amit Fail
# Priya Not Eligible
# Neha Pass
# Rohit Not Eligible
